# %% [markdown]
# # Tópicos
# - Gerar análises com a base de dados de janeiro
# - Criar uma função para gerar esses gráficos
# - Salvar os gráficos como imagens para utilização posterior em powerpoints ou documentos
#
#
# # Índice
#
# 1. [Importando bibliotecas](#import)
# 2. [Carregando o dataframe SINASC](#read)
# 2. [Gráficos](#cont_idade_mae)
#     2. [Contagem da IDADEMAE x Tempo ](#exemplo_1)
#     2. [Quantidade de bebês ao longo do ano](#exemplo_2)
#     2. [Quantidade de bebês fem e masc por mês](#exemplo_3)
#     2. [Média peso dos bebês fem e masc](#exemplo_4)
#     2. [Peso x Escolaridade mãe (ESCMAE)](#exemplo_5)
#     2. [Gestacão](#exemplo_6)
# 2. [Utilizando função](#funcao)
# 2. [Salvando os gráficos](#salvando)

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


sns.set_theme()

# %%
def plota_pivot_table(df, value, index, func, ylabel, xlabel, opcao='nada'):
    if opcao == 'nada':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).plot(figsize=[15, 5])
    elif opcao == 'sort':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).sort_values(value).plot(figsize=[15, 5])
    elif opcao == 'unstack':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).unstack().plot(figsize=[15, 5])
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    return None

# %% [markdown]
# # 2. Carregando o dataframe SINASC <a name="read"></a>

# %% [markdown]
# ![Janeiro](imagens/Jan.png)

# %%
sinasc = pd.read_csv('SINASC_RO_2019_JAN.csv')
sinasc.head()
# Out:
#    Unnamed: 0  ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0          72       1  6663834.0      110002        1        29        2.0
# 1          73       1  6663834.0      110002        1        25        2.0
# 2          74       1  2515601.0      110002        1        35        2.0
# 3          75       1  2515601.0      110002        1        24        2.0
# 4          76       1  2515601.0      110002        1        26        1.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  ...  KOTELCHUCK  CONTADOR  \
# 0  12 anos ou mais    999992.0         0.0  ...           5        73
# 1  12 anos ou mais    999992.0         0.0  ...           5        74
# 2      8 a 11 anos    999992.0         1.0  ...           5        75
# 3  12 anos ou mais    524105.0         0.0  ...           4        76
# 4  12 anos ou mais    999992.0         0.0  ...           5        77
#
#   munResStatus munResTipo    munResNome  munResUf munResLat  munResLon  \
# 0        ATIVO      MUNIC     Ariquemes  Rondônia  -9.90846  -63.03327
# 1        ATIVO      MUNIC       Cujubim  Rondônia  -9.37819  -62.58717
# 2        ATIVO      MUNIC     Ariquemes  Rondônia  -9.90846  -63.03327
# 3        ATIVO      MUNIC  Alto Paraíso  Rondônia  -9.71667  -63.31763
# 4        ATIVO      MUNIC     Ariquemes  Rondônia  -9.90846  -63.03327
#
#   munResAlt  munResArea
# 0     139.0    4426.571
# 1     111.0    3863.943
# 2     139.0    4426.571
# 3     128.0    2651.822
# 4     139.0    4426.571
#
# [5 rows x 70 columns]

# %% [markdown]
# # 3. Gráficos

# %% [markdown]
# ## 3.1 Contagem da IDADEMAE x Tempo  <a name="exemplo_1"></a>

# %%
pd.pivot_table(sinasc, values='IDADEMAE', index='DTNASC',
               aggfunc='mean').plot(figsize=[15, 5])
plt.ylabel('média idade mãe');

# %% [markdown]
# ## 3.2 Quantidade de bebês ao longo do ano <a name="exemplo_2"></a>

# %%
pd.pivot_table(sinasc, values='IDADEMAE', index='DTNASC',
               aggfunc='count').plot(figsize=[18, 6])
plt.ylabel('quantidade de nascimentos');

# %% [markdown]
# ## 3.3 Quantidade de bebês fem e masc por mês <a name="exemplo_3"></a>

# %%
pd.pivot_table(sinasc, values='IDADEMAE', index=['DTNASC', 'SEXO'],
               aggfunc='count').unstack().plot(figsize=[18, 6]);

# %% [markdown]
# ## 3.4 Média peso dos bebês fem e masc<a name="exemplo_4"></a>

# %%
pd.pivot_table(sinasc, values='PESO', index=['DTNASC', 'SEXO'],
               aggfunc='count').unstack().plot(figsize=[18, 6]);

# %% [markdown]
# ## 3.5 Peso x Escolaridade mãe (ESCMAE) <a name="exemplo_5"></a>

# %%
pd.pivot_table(sinasc, values='PESO', index=['ESCMAE'],
               aggfunc='median').sort_values('PESO').plot(figsize=[18, 6]);

# %% [markdown]
# ## 3.6 Gestacão <a name="exemplo_6"></a>

# %%
pd.pivot_table(sinasc, values='APGAR1', index=['GESTACAO'],
               aggfunc='mean').sort_values('APGAR1').plot(figsize=[18, 6])
plt.ylabel('apgar1 medio')
plt.xlabel('gestacao');

# %%
pd.pivot_table(sinasc, values='APGAR5', index=['GESTACAO'],
               aggfunc='mean').sort_values('APGAR5').plot(figsize=[18, 6])
plt.ylabel('apgar5 medio')
plt.xlabel('gestacao');

# %% [markdown]
# # 4. Utilizando função <a name="funcao"></a>

# %%
max_data = sinasc.DTNASC.max()[:7]
max_data
# Out:
# '2019-01'

# %%
plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'count', 'quantidade de nascimento','data de nascimento')

# %% [markdown]
# # 5. Salvando os gráficos <a name="salvando"></a>

# %%
import os

# %%
pwd
# Out:
# 'D:\\lucas_000\\Documents\\EBAC\\modulos\\Módulo 14'

# %%
max_data = sinasc.DTNASC.max()[:7]
max_data
# Out:
# '2019-01'

# %%
os.makedirs('./output/figs/'+max_data, exist_ok=True)

# %%
plota_pivot_table(sinasc, 'IDADEMAE', ['DTNASC', 'SEXO'], 'mean', 'media idade mae','data de nascimento','unstack')
plt.savefig('./output/figs/'+max_data+'/media idade mae por sexo.png')

# %%
plota_pivot_table(sinasc, 'PESO', ['DTNASC', 'SEXO'], 'mean', 'media peso bebe','data de nascimento','unstack')
plt.savefig('./output/figs/'+max_data+'/media peso bebe por sexo.png')

# %%
plota_pivot_table(sinasc, 'PESO', 'ESCMAE', 'median', 'apgar1 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar1 por escolaridade mae.png')

# %%
plota_pivot_table(sinasc, 'APGAR1', 'GESTACAO', 'mean', 'apgar1 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar1 por gestacao.png')

# %%
plota_pivot_table(sinasc, 'APGAR5', 'GESTACAO', 'mean', 'apgar5 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar5 por gestacao.png')

# %% [markdown]
# # Célula única - janeiro

# %% [markdown]
# ![Janeiro](imagens/Jan.png)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme()  

def plota_pivot_table(df, value, index, func, ylabel, xlabel, opcao='nada'):
    if opcao == 'nada':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).plot(figsize=[15, 5])
    elif opcao == 'sort':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).sort_values(value).plot(figsize=[15, 5])
    elif opcao == 'unstack':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).unstack().plot(figsize=[15, 5])
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    return None

sinasc = pd.read_csv('SINASC_RO_2019_JAN.csv')
print(sinasc.DTNASC.min(), sinasc.DTNASC.max())

max_data = sinasc.DTNASC.max()[:7]
print(max_data)
os.makedirs('./output/figs/'+max_data, exist_ok=True)


plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'count', 'quantidade de nascimento','data de nascimento')
plt.savefig('./output/figs/'+max_data+'/quantidade de nascimento.png')

plota_pivot_table(sinasc, 'IDADEMAE', ['DTNASC', 'SEXO'], 'mean', 'media idade mae','data de nascimento','unstack')
plt.savefig('./output/figs/'+max_data+'/media idade mae por sexo.png')

plota_pivot_table(sinasc, 'PESO', ['DTNASC', 'SEXO'], 'mean', 'media peso bebe','data de nascimento','unstack')
plt.savefig('./output/figs/'+max_data+'/media peso bebe por sexo.png')

plota_pivot_table(sinasc, 'PESO', 'ESCMAE', 'median', 'apgar1 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar1 por escolaridade mae.png')

plota_pivot_table(sinasc, 'APGAR1', 'GESTACAO', 'mean', 'apgar1 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar1 por gestacao.png')

plota_pivot_table(sinasc, 'APGAR5', 'GESTACAO', 'mean', 'apgar5 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar5 por gestacao.png')
# Out:
# 2019-01-01 2019-01-31
# 2019-01

# %% [markdown]
# # Célula única - fevereiro

# %% [markdown]
# ![Fevereiro](imagens/Fev.png)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme()  

def plota_pivot_table(df, value, index, func, ylabel, xlabel, opcao='nada'):
    if opcao == 'nada':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).plot(figsize=[15, 5])
    elif opcao == 'sort':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).sort_values(value).plot(figsize=[15, 5])
    elif opcao == 'unstack':
        pd.pivot_table(df, values=value, index=index,
                       aggfunc=func).unstack().plot(figsize=[15, 5])
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    return None

sinasc = pd.read_csv('SINASC_RO_2019_FEV.csv')
print(sinasc.DTNASC.min(), sinasc.DTNASC.max())

max_data = sinasc.DTNASC.max()[:7]
print(max_data)
os.makedirs('./output/figs/'+max_data, exist_ok=True)


plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'count', 'quantidade de nascimento','data de nascimento')
plt.savefig('./output/figs/'+max_data+'/quantidade de nascimento.png')

plota_pivot_table(sinasc, 'IDADEMAE', ['DTNASC', 'SEXO'], 'mean', 'media idade mae','data de nascimento','unstack')
plt.savefig('./output/figs/'+max_data+'/media idade mae por sexo.png')

plota_pivot_table(sinasc, 'PESO', ['DTNASC', 'SEXO'], 'mean', 'media peso bebe','data de nascimento','unstack')
plt.savefig('./output/figs/'+max_data+'/media peso bebe por sexo.png')

plota_pivot_table(sinasc, 'PESO', 'ESCMAE', 'median', 'apgar1 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar1 por escolaridade mae.png')

plota_pivot_table(sinasc, 'APGAR1', 'GESTACAO', 'mean', 'apgar1 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar1 por gestacao.png')

plota_pivot_table(sinasc, 'APGAR5', 'GESTACAO', 'mean', 'apgar5 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar5 por gestacao.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/henriquerocha/Documents/EBAC-AULAS/MODULO 14/Mod14Aula2.ipynb Cell 43' in <cell line: 20>()
#      <a href='vscode-notebook-cell:/Users/henriquerocha/Documents/EBAC-AULAS/MODULO%2014/Mod14Aula2.ipynb#ch0000042?line=16'>17</a>     plt.xlabel(xlabel)
#      <a href='vscode-notebook-cell:/Users/henriquerocha/Documents/EBAC-AULAS/MODULO%2014/Mod14Aula2.ipynb#ch0000042?line=17'>18</a>     return None
# ---> <a href='vscode-notebook-cell:/Users/henriquerocha/Documents/EBAC-AULAS/MODULO%2014/Mod14Aula2.ipynb#ch0000042?line=19'>20</a> sinasc = pd.read_csv('SINASC_RO_2019_FEV.csv')
#      <a href='vscode-notebook-cell:/Users/henriquerocha/Documents/EBAC-AULAS/MODULO%2014/Mod14Aula2.ipynb#ch0000042?line=20'>21</a> print(sinasc.DTNASC.min(), sinasc.DTNASC.max())
#      <a href='vscode-notebook-cell:/Users/henriquerocha/Documents/EBAC-AULAS/MODULO%2014/Mod14Aula2.ipynb#ch0000042?line=22'>23</a> max_data = sinasc.DTNASC.max()[:7]
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/io/parsers/readers.py:934, in TextFileReader.__init__(self, f, engine, **kwds)
#     931     self.options["has_index_names"] = kwds["has_index_names"]
#     933 self.handles: IOHandles | None = None
# --> 934 self._engine = self._make_engine(f, self.engine)
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/io/parsers/readers.py:1218, in TextFileReader._make_engine(self, f, engine)
#    1214     mode = "rb"
#    1215 # error: No overload variant of "get_handle" matches argument types
#    1216 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1217 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1218 self.handles = get_handle(  # type: ignore[call-overload]
#    1219     f,
#    1220     mode,
#    1221     encoding=self.options.get("encoding", None),
#    1222     compression=self.options.get("compression", None),
#    1223     memory_map=self.options.get("memory_map", False),
#    1224     is_text=is_text,
#    1225     errors=self.options.get("encoding_errors", "strict"),
#    1226     storage_options=self.options.get("storage_options", None),
#    1227 )
#    1228 assert self.handles is not None
#    1229 f = self.handles.handle
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/io/common.py:786, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     781 elif isinstance(handle, str):
#     782     # Check whether the filename is to be opened in binary mode.
#     783     # Binary mode does not support 'encoding' and 'newline'.
#     784     if ioargs.encoding and "b" not in ioargs.mode:
#     785         # Encoding
# --> 786         handle = open(
#     787             handle,
#     788             ioargs.mode,
#     789             encoding=ioargs.encoding,
#     790             errors=errors,
#     791             newline="",
#     792         )
#     793     else:
#     794         # Binary mode
#     795         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'SINASC_RO_2019_FEV.csv'
